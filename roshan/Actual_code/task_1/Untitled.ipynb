# %%
from openai import OpenAI

client = OpenAI(
    base_url="http://127.0.0.1:8000/v1",
    api_key="local",
)

resp = client.chat.completions.create(
    model="Qwen/Qwen2.5-14B-Instruct",
    messages=[{"role": "user", "content": "Whats ur fav color?"}],
    temperature=0,
)

print(resp.choices[0].message.content)
# Out:
# As an artificial intelligence, I don't have personal preferences or physical senses, so I don't have a favorite color. However, I can help you with information or tasks related to colors if you need!
