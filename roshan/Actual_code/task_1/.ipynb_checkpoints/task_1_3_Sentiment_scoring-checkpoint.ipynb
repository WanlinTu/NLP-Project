# %% [markdown]
# # Task 1 — Thematic Factor Discovery: Sentiment Scoring
#
# Covers **Task 1, Sub-step 3**: use the LLM to assign 5-class sentiment labels to every factor extracted in Sub-step 2.
#
# For each filing's factor JSON, the LLM scores factors in batches of 8, assigning a label, rationale, and confidence.
#
# | | |
# |---|---|
# | **Input** | `output/factors/{TICKER}/{STEM}_factors.json` |
# | **Output** | `output/factors_scored/{TICKER}/{STEM}_factors.json` |
# | **Model** | `deepseek-ai/DeepSeek-R1-Distill-Qwen-14B` via vLLM on ACCRE |
# | **GPU** | Required — DGX A100 40GB |
#
# | Label | Meaning |
# |---|---|
# | `very_negative` | Clear, significant deterioration or major risk |
# | `negative` | Moderate headwind, declining trend, or concern |
# | `neutral` | Stable, mixed signals, or no clear directional signal |
# | `positive` | Moderate improvement, tailwind, or opportunity |
# | `very_positive` | Clear, significant improvement or major positive development |

# %% [markdown]
# ## Step 1: Imports & Configuration
#
# Set up paths, logging, and LLM constants. The vLLM server must be running before executing Step 3+.

# %%
# !pip install -r requirements.txt
# Out:
# Looking in links: /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo2023/x86-64-v3, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo2023/generic, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/generic
# Requirement already satisfied: beautifulsoup4 in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (4.14.3+computecanada)
# Requirement already satisfied: lxml in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (5.3.1+computecanada)
# Requirement already satisfied: openai in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (2.26.0)
# Requirement already satisfied: pydantic in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (2.12.5+computecanada)
# Requirement already satisfied: tqdm in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (4.67.3+computecanada)
# Requirement already satisfied: numpy in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2025a/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (2.2.2+computecanada)
# Requirement already satisfied: pandas in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2025a/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (2.2.3+computecanada)
# Requirement already satisfied: matplotlib in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2025a/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (3.10.0+computecanada)
# Requirement already satisfied: seaborn in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (0.13.2+computecanada)
# Requirement already satisfied: scipy in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2025a/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (1.15.1+computecanada)
# Requirement already satisfied: yfinance in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (1.2.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from beautifulsoup4->-r requirements.txt (line 1)) (2.8.3+computecanada)
# Requirement already satisfied: typing-extensions>=4.0.0 in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from beautifulsoup4->-r requirements.txt (line 1)) (4.15.0+computecanada)
# Requirement already satisfied: anyio<5,>=3.5.0 in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from openai->-r requirements.txt (line 3)) (4.12.1+computecanada)
# Requirement already satisfied: distro<2,>=1.7.0 in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from openai->-r requirements.txt (line 3)) (1.9.0+computecanada)
# Requirement already satisfied: httpx<1,>=0.23.0 in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from openai->-r requirements.txt (line 3)) (0.28.1+computecanada)
# Requirement already satisfied: jiter<1,>=0.10.0 in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from openai->-r requirements.txt (line 3)) (0.11.1+computecanada)
# Requirement already satisfied: sniffio in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from openai->-r requirements.txt (line 3)) (1.3.1+computecanada)
# Requirement already satisfied: annotated-types>=0.6.0 in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from pydantic->-r requirements.txt (line 4)) (0.7.0+computecanada)
# Requirement already satisfied: pydantic-core==2.41.5 in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from pydantic->-r requirements.txt (line 4)) (2.41.5+computecanada)
# Requirement already satisfied: typing-inspection>=0.4.2 in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from pydantic->-r requirements.txt (line 4)) (0.4.2+computecanada)
# Requirement already satisfied: idna>=2.8 in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 3)) (3.11+computecanada)
# Requirement already satisfied: certifi in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 3)) (2026.1.4+computecanada)
# Requirement already satisfied: httpcore==1.* in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 3)) (1.0.9+computecanada)
# Requirement already satisfied: h11>=0.16 in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r requirements.txt (line 3)) (0.16.0+computecanada)
# Requirement already satisfied: python-dateutil>=2.8.2 in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2025a/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 7)) (2.9.0.post0+computecanada)
# Requirement already satisfied: pytz>=2020.1 in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2025a/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 7)) (2025.1+computecanada)
# Requirement already satisfied: tzdata>=2022.7 in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2025a/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 7)) (2025.1+computecanada)
# Requirement already satisfied: contourpy>=1.0.1 in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2025a/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 8)) (1.3.1+computecanada)
# Requirement already satisfied: cycler>=0.10 in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2025a/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 8)) (0.12.1+computecanada)
# Requirement already satisfied: fonttools>=4.22.0 in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2025a/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 8)) (4.55.8+computecanada)
# Requirement already satisfied: kiwisolver>=1.3.1 in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2025a/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 8)) (1.4.8+computecanada)
# Requirement already satisfied: packaging>=20.0 in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2025a/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 8)) (24.2+computecanada)
# Requirement already satisfied: pillow>=8 in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2025a/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 8)) (11.1.0+computecanada)
# Requirement already satisfied: pyparsing>=2.3.1 in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2025a/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 8)) (3.2.1+computecanada)
# Requirement already satisfied: requests>=2.31 in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from yfinance->-r requirements.txt (line 11)) (2.32.5+computecanada)
# Requirement already satisfied: multitasking>=0.0.7 in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from yfinance->-r requirements.txt (line 11)) (0.0.11+computecanada)
# Requirement already satisfied: platformdirs>=2.0.0 in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/ipykernel/2025a/lib/python3.12/site-packages (from yfinance->-r requirements.txt (line 11)) (4.3.6+computecanada)
# Requirement already satisfied: frozendict>=2.3.4 in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from yfinance->-r requirements.txt (line 11)) (2.4.7+computecanada)
# Requirement already satisfied: peewee>=3.16.2 in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from yfinance->-r requirements.txt (line 11)) (4.0.1)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from yfinance->-r requirements.txt (line 11)) (0.11.3+computecanada)
# Requirement already satisfied: protobuf>=3.19.0 in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from yfinance->-r requirements.txt (line 11)) (7.34.0)
# Requirement already satisfied: websockets>=13.0 in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from yfinance->-r requirements.txt (line 11)) (16.0+computecanada)
# Requirement already satisfied: cffi>=1.12.0 in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from curl_cffi<0.14,>=0.7->yfinance->-r requirements.txt (line 11)) (2.0.0+computecanada)
# Requirement already satisfied: pycparser in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance->-r requirements.txt (line 11)) (3.0+computecanada)
# Requirement already satisfied: six>=1.5 in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2025a/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 7)) (1.17.0+computecanada)
# Requirement already satisfied: charset-normalizer<4,>=2 in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from requests>=2.31->yfinance->-r requirements.txt (line 11)) (3.4.4+computecanada)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /tmp/u941451.j9336222.CWQ9/venv/lib/python3.12/site-packages (from requests>=2.31->yfinance->-r requirements.txt (line 11)) (2.6.3+computecanada)

# %%
import json
import logging
import sys
import time
import threading
import re
from concurrent.futures import ThreadPoolExecutor, as_completed
from pathlib import Path
from typing import Any, Optional, List

from pydantic import BaseModel
from openai import OpenAI
from tqdm.notebook import tqdm

# ── Paths ────────────────────────────────────────────────────────────────
_cwd = Path.cwd()

_search = _cwd
FILLINGS_ROOT = None
for _ in range(6):
    if (_search / "Data").is_dir():
        FILLINGS_ROOT = _search
        break
    _search = _search.parent

if FILLINGS_ROOT is None:
    raise FileNotFoundError(
        f"Could not find Data/ directory in any parent of {_cwd}. "
        "Make sure the notebook is inside the fillings/ project tree."
    )

FACTORS_DIR = _cwd / "output" / "factors"
FACTORS_SCORED_DIR = _cwd / "output" / "factors_scored"
TICKER_MAPPING_PATH = _cwd / "ticker_mapping.json"

FACTORS_SCORED_DIR.mkdir(parents=True, exist_ok=True)

# ── LLM Constants ────────────────────────────────────────────────────────
BASE_URL = "http://127.0.0.1:8000/v1"
API_KEY = "local"
MODEL = "deepseek-ai/DeepSeek-R1-Distill-Qwen-14B"
TEMPERATURE = 0.6              # DeepSeek-R1 recommends 0.6
MAX_RETRIES = 5
RETRY_BASE_DELAY = 2.0
REQUEST_TIMEOUT = 600          # reasoning models are slower
MAX_IN_FLIGHT_LLM = 4
SCORING_MAX_TOKENS = 8192      # headroom for <think> + JSON output

# ── Scoring Constants ─────────────────────────────────────────────────────
BATCH_SIZE = 8  # factors per LLM call

# ── Logging ──────────────────────────────────────────────────────────────
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s | %(levelname)-7s | %(message)s",
    datefmt="%H:%M:%S",
    handlers=[logging.StreamHandler(sys.stdout)],
    force=True,
)
log = logging.getLogger("task_1_3")

# ── Pydantic Response Schemas ────────────────────────────────────────────

class SentimentScore(BaseModel):
    key: str
    label: str
    rationale: str = ""
    confidence: float = 0.5

class SentimentBatchResponse(BaseModel):
    scores: List[SentimentScore]

print(f"Fillings root:        {FILLINGS_ROOT}")
print(f"Factors dir (input):  {FACTORS_DIR} (exists={FACTORS_DIR.exists()})")
print(f"Scored dir (output):  {FACTORS_SCORED_DIR}")
print(f"Ticker mapping:       {TICKER_MAPPING_PATH} (exists={TICKER_MAPPING_PATH.exists()})")
print(f"Model:                {MODEL}")
print(f"Temperature:          {TEMPERATURE}")
print(f"Batch size:           {BATCH_SIZE} factors per LLM call")
print(f"Concurrency:          {MAX_IN_FLIGHT_LLM} in-flight LLM calls")
print(f"JSON enforcement:     response_format=json_object + Pydantic validation")
# Out:
# Fillings root:        /panfs/accrepfs.vampire/home/sivakur/asset/fillings
# Factors dir (input):  /panfs/accrepfs.vampire/home/sivakur/asset/fillings/roshan/Actual_code/task_1/output/factors (exists=True)
# Scored dir (output):  /panfs/accrepfs.vampire/home/sivakur/asset/fillings/roshan/Actual_code/task_1/output/factors_scored
# Ticker mapping:       /panfs/accrepfs.vampire/home/sivakur/asset/fillings/roshan/Actual_code/task_1/ticker_mapping.json (exists=True)
# Model:                deepseek-ai/DeepSeek-R1-Distill-Qwen-14B
# Temperature:          0.6
# Batch size:           8 factors per LLM call
# Concurrency:          4 in-flight LLM calls
# JSON enforcement:     response_format=json_object + Pydantic validation

# %% [markdown]
# ## Step 2: LLM Client Utilities
#
# OpenAI-compatible client with:
# - **Concurrency control** — `BoundedSemaphore` limits concurrent LLM calls
# - **Exponential backoff** — retries on transient failures
# - **JSON parsing** — strips markdown code blocks, extracts JSON from mixed output

# %%
# Global concurrency limiter
_semaphore = threading.BoundedSemaphore(MAX_IN_FLIGHT_LLM)


def call_llm(
    client: OpenAI,
    system_prompt: str,
    user_prompt: str,
    temperature: float = TEMPERATURE,
    max_tokens: int = SCORING_MAX_TOKENS,
    force_json: bool = False,
) -> Optional[str]:
    """
    Call the LLM with retry logic and concurrency control.
    If force_json=True, adds response_format={"type": "json_object"} to force valid JSON.
    """
    kwargs: dict[str, Any] = {
        "model": MODEL,
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt},
        ],
        "temperature": temperature,
        "max_tokens": max_tokens,
        "timeout": REQUEST_TIMEOUT,
    }

    if force_json:
        kwargs["response_format"] = {"type": "json_object"}

    for attempt in range(1, MAX_RETRIES + 1):
        try:
            with _semaphore:
                response = client.chat.completions.create(**kwargs)
            return response.choices[0].message.content

        except Exception as e:
            delay = RETRY_BASE_DELAY * (2 ** (attempt - 1))
            log.warning(
                f"  LLM call attempt {attempt}/{MAX_RETRIES} failed: {e}. "
                f"Retrying in {delay}s..."
            )
            if attempt < MAX_RETRIES:
                time.sleep(delay)
            else:
                log.error(f"  LLM call failed after {MAX_RETRIES} attempts: {e}")
                return None


def parse_json_response(content: str) -> Optional[Any]:
    """Parse JSON from LLM response, handling markdown code blocks and <think> tags."""
    content = content.strip()

    # Strip closed <think>...</think> blocks (DeepSeek-R1 reasoning output)
    content = re.sub(r"<think>.*?</think>", "", content, flags=re.DOTALL).strip()

    # Strip unclosed <think> blocks (truncated reasoning — no closing tag)
    if "<think>" in content:
        content = re.sub(r"<think>.*", "", content, flags=re.DOTALL).strip()

    # Strip markdown code blocks if present
    if content.startswith("```"):
        content = content.split("\n", 1)[1] if "\n" in content else content[3:]
        if content.endswith("```"):
            content = content[:-3]
        content = content.strip()

    try:
        return json.loads(content)
    except json.JSONDecodeError:
        pass

    # Fallback: find the first { or [ and last } or ]
    start_obj = content.find("{")
    start_arr = content.find("[")
    if start_obj == -1 and start_arr == -1:
        log.error(f"  No JSON found in response: {content[:200]}...")
        return None

    if start_arr != -1 and (start_obj == -1 or start_arr < start_obj):
        start = start_arr
        end = content.rfind("]")
    else:
        start = start_obj
        end = content.rfind("}")

    if end == -1 or end <= start:
        log.error(f"  Malformed JSON in response: {content[:200]}...")
        return None

    try:
        return json.loads(content[start:end + 1])
    except json.JSONDecodeError as e:
        log.error(f"  JSON parse error: {e}. Content: {content[start:start+200]}...")
        return None


def call_llm_json(
    client: OpenAI,
    system_prompt: str,
    user_prompt: str,
    temperature: float = TEMPERATURE,
    max_tokens: int = SCORING_MAX_TOKENS,
    response_model: Optional[type[BaseModel]] = None,
) -> Optional[Any]:
    """
    Call the LLM and parse the response as JSON.
    Uses response_format=json_object to force valid JSON output.
    If response_model is provided, validates with Pydantic after parsing.
    """
    content = call_llm(
        client, system_prompt, user_prompt,
        temperature, max_tokens,
        force_json=True,
    )
    if content is None:
        return None

    parsed = parse_json_response(content)
    if parsed is None:
        return None

    # Validate with Pydantic if response_model is provided
    if response_model is not None:
        try:
            validated = response_model.model_validate(parsed)
            return validated.model_dump()
        except Exception as e:
            log.error(f"  Pydantic validation failed: {e}")
            return None

    return parsed


# ── Create client & health check ─────────────────────────────────────────
client = OpenAI(base_url=BASE_URL, api_key=API_KEY)

try:
    models = client.models.list()
    available = [m.id for m in models.data]
    print(f"vLLM is reachable. Available models: {available}")
    if MODEL not in available:
        print(f"WARNING: {MODEL} not in available models!")
except Exception as e:
    print(f"WARNING: vLLM health check failed: {e}")
    print("The LLM server must be running before executing Steps 3+.")
# Out:
# 22:00:45 | INFO    | HTTP Request: GET http://127.0.0.1:8000/v1/models "HTTP/1.1 200 OK"
# vLLM is reachable. Available models: ['deepseek-ai/DeepSeek-R1-Distill-Qwen-14B']

# %% [markdown]
# ## Step 3: Sentiment Scoring Logic
#
# Each batch of factors is sent to the LLM with their summary and evidence.
# The LLM returns a 5-class sentiment label, a 1-sentence rationale, and a confidence score.
#
# - **`build_sentiment_prompt()`** — formats factors into a structured prompt
# - **`score_batch()`** — calls the LLM, parses and validates the response

# %%
SENTIMENT_SYSTEM_PROMPT = """\
You are a financial analyst assigning sentiment labels to thematic factors extracted from SEC filings. Respond with valid JSON matching the required schema."""

VALID_LABELS = {"very_negative", "negative", "neutral", "positive", "very_positive"}


def build_sentiment_prompt(factors_batch: list[dict]) -> str:
    """Build user prompt for a batch of factors."""
    blocks = []
    for factor in factors_batch:
        evidence_text = "\n".join(
            f"  - \"{e['text']}\""
            for e in factor.get("evidence", [])
            if isinstance(e, dict) and e.get("text")
        )
        blocks.append(
            f"### Factor: {factor['key']} (category: {factor['category']})\n"
            f"Summary: {factor['summary']}\n"
            f"Evidence:\n{evidence_text}"
        )

    return "\n\n".join(blocks) + """

Assign a sentiment label to each factor above.

For each factor, include it in the "scores" array with:
- "key": the factor key
- "label": one of "very_negative", "negative", "neutral", "positive", "very_positive"
- "rationale": 1 sentence explaining why you chose this label
- "confidence": float 0.0 to 1.0

Label definitions:
- "very_negative": Clear, significant deterioration or major risk
- "negative": Moderate headwind, declining trend, or concern
- "neutral": Stable, mixed signals, or no clear directional signal
- "positive": Moderate improvement, tailwind, or opportunity
- "very_positive": Clear, significant improvement or major positive development

Rules:
- Base your label ONLY on the summary and evidence provided
- Be decisive — avoid defaulting to "neutral" unless genuinely mixed
- Confidence should reflect how clearly the text supports a directional reading"""


def score_batch(
    client: OpenAI, factors_batch: list[dict]
) -> dict[str, dict]:
    """
    Score a batch of factors for sentiment.
    Uses response_format=json_object + Pydantic validation.

    Returns {factor_key: {label, rationale, confidence}} for successfully scored factors.
    """
    prompt = build_sentiment_prompt(factors_batch)
    result = call_llm_json(
        client, SENTIMENT_SYSTEM_PROMPT, prompt,
        max_tokens=SCORING_MAX_TOKENS,
        response_model=SentimentBatchResponse,
    )

    if result is None:
        log.warning(
            f"    Sentiment LLM returned invalid result for batch of {len(factors_batch)}"
        )
        return {}

    scores = result.get("scores", [])
    scored: dict[str, dict] = {}
    for item in scores:
        if not isinstance(item, dict):
            continue
        key = item.get("key")
        label = item.get("label")
        if not key or label not in VALID_LABELS:
            continue
        scored[key] = {
            "label": label,
            "rationale": item.get("rationale", ""),
            "confidence": min(1.0, max(0.0, float(item.get("confidence", 0.5)))),
        }

    return scored


print("Sentiment scoring functions loaded.")
print(f"Valid labels: {sorted(VALID_LABELS)}")
print(f"Batch size: {BATCH_SIZE} factors per LLM call")
# Out:
# Sentiment scoring functions loaded.
# Valid labels: ['negative', 'neutral', 'positive', 'very_negative', 'very_positive']
# Batch size: 8 factors per LLM call

# %% [markdown]
# ## Step 4: Filing-Level Processing
#
# Loads one factor JSON, batches its factors into groups of `BATCH_SIZE`, and scores all batches
# **concurrently** via `ThreadPoolExecutor` (same pattern as task_1_2).
#
# Each filing has ~30 factors → ~4 batches of 8 → all sent in parallel → completes in one round-trip (~10s) instead of four (~40s).

# %%
def process_filing(factor_file: Path, client: OpenAI) -> dict | None:
    """
    Score all factors in one filing for sentiment.

    Batches are scored concurrently via ThreadPoolExecutor to leverage
    vLLM's continuous batching on the GPU.

    Returns the updated factor JSON with sentiment populated, or None if
    no factors were successfully scored (so resume-safe skip doesn't
    prevent retrying on next run).
    """
    with open(factor_file) as f:
        data = json.load(f)

    factors = data.get("factors", [])
    if not factors:
        return None

    # Build batches
    batches = [
        factors[i : i + BATCH_SIZE]
        for i in range(0, len(factors), BATCH_SIZE)
    ]

    # Score all batches concurrently
    all_scored: dict[str, dict] = {}

    with ThreadPoolExecutor(max_workers=MAX_IN_FLIGHT_LLM) as pool:
        futures = {
            pool.submit(score_batch, client, batch): i
            for i, batch in enumerate(batches)
        }
        for future in as_completed(futures):
            batch_idx = futures[future]
            try:
                scored = future.result()
                all_scored.update(scored)
            except Exception as e:
                log.warning(f"    Batch {batch_idx} failed: {e}")

    # Apply sentiment labels to factors
    scored_count = 0
    for factor in factors:
        sentiment = all_scored.get(factor["key"])
        if sentiment:
            factor["sentiment"] = sentiment
            scored_count += 1
        else:
            factor["sentiment"] = None

    log.info(
        f"  {data['ticker']} {data['form']} {data['filing_date']}: "
        f"{scored_count}/{len(factors)} factors scored"
    )

    # Don't save if nothing was scored — allows retry on next run
    if scored_count == 0:
        log.warning(
            f"  {data['ticker']} {data['filing_date']}: 0 factors scored, skipping save"
        )
        return None

    return data


print("Filing-level processing function loaded.")
# Out:
# Filing-level processing function loaded.

# %% [markdown]
# ## Step 5: Filing Discovery
#
# Load tickers, discover factor files, compute output paths, and check resume state.
# Prints a dry-run summary before actual processing.

# %%
# Load tickers
with open(TICKER_MAPPING_PATH) as f:
    ticker_mapping = json.load(f)

all_tickers = sorted(
    t for sector_list in ticker_mapping.values() for t in sector_list
)
print(f"Loaded {len(all_tickers)} tickers across {len(ticker_mapping)} sub-sectors")


# ── Dry-run summary ───────────────────────────────────────────────────────
total_files = 0
total_already = 0
total_remaining = 0
tickers_with_data = 0
tickers_no_data = []

for ticker in all_tickers:
    ticker_input = FACTORS_DIR / ticker
    if not ticker_input.exists():
        tickers_no_data.append(ticker)
        continue

    factor_files = sorted(ticker_input.glob("*_factors.json"))
    if not factor_files:
        tickers_no_data.append(ticker)
        continue

    tickers_with_data += 1
    ticker_output = FACTORS_SCORED_DIR / ticker

    for ff in factor_files:
        total_files += 1
        out_file = ticker_output / ff.name
        if out_file.exists():
            total_already += 1
        else:
            total_remaining += 1

print(f"\n{tickers_with_data}/{len(all_tickers)} tickers have factor files")
print(f"{total_files} total factor files")
print(f"{total_already} already scored (will be skipped)")
print(f"{total_remaining} remaining to score")

if tickers_no_data:
    print(
        f"\nTickers with no factor data ({len(tickers_no_data)}): "
        f"{', '.join(tickers_no_data)}"
    )
# Out:
# Loaded 86 tickers across 4 sub-sectors
#
# 29/86 tickers have factor files
# 1052 total factor files
# 735 already scored (will be skipped)
# 317 remaining to score
#
# Tickers with no factor data (57): FLR, FLS, FTV, GD, GE, GNRC, GWW, HII, HON, HUBB, INFO, IR, ITW, J, JBHT, JCI, KSU, LDOS, LHX, LII, LLL, LMT, LUV, MAS, MMM, NDSN, NLSN, NOC, NSC, ODFL, OTIS, PCAR, PH, PNR, PWR, R, RHI, ROK, ROL, ROP, RSG, RTN, RTX, SNA, SWK, TDG, TT, TXT, UAL, UNP, UPS, URI, VNT, VRSK, WAB, WM, XYL

# %% [markdown]
# ## Step 6: Run Sentiment Scoring
#
# Main processing loop. For each filing:
# 1. Skip if output already exists (resume-safe)
# 2. Call `process_filing()` to score all factors
# 3. Write scored factor JSON to `output/factors_scored/`

# %%
# Build flat list of (ticker, factor_file) pairs
all_jobs: list[tuple[str, Path]] = []
for ticker in all_tickers:
    ticker_input = FACTORS_DIR / ticker
    if not ticker_input.exists():
        continue
    for ff in sorted(ticker_input.glob("*_factors.json")):
        all_jobs.append((ticker, ff))

print(f"{len(all_jobs)} filing jobs queued")

g_ok = g_skip = g_err = g_scored = 0

pbar = tqdm(all_jobs, desc="Sentiment scoring", unit="filing")
for ticker, factor_file in pbar:
    ticker_output = FACTORS_SCORED_DIR / ticker
    ticker_output.mkdir(parents=True, exist_ok=True)

    out_file = ticker_output / factor_file.name

    # Resume-safe
    if out_file.exists():
        g_skip += 1
        pbar.set_postfix(ok=g_ok, skip=g_skip, err=g_err, scored=g_scored)
        continue

    try:
        result = process_filing(factor_file, client)
        if result:
            with open(out_file, "w") as f:
                json.dump(result, f, indent=2)
            g_ok += 1
            g_scored += sum(
                1 for fac in result["factors"]
                if fac.get("sentiment") is not None
            )
        else:
            g_err += 1
    except Exception as e:
        g_err += 1
        log.error(f"  {factor_file.name}: CRASHED -- {e}")

    pbar.set_postfix(ok=g_ok, skip=g_skip, err=g_err, scored=g_scored)

print(f"\nDone. {g_ok} processed, {g_skip} skipped, {g_err} errors")
print(f"Total factors scored: {g_scored}")
if g_ok > 0:
    print(f"Avg factors/filing: {g_scored / g_ok:.1f}")
# Out:
# 1052 filing jobs queued
# Sentiment scoring:   0%|          | 0/1052 [00:00<?, ?filing/s]
# 22:00:54 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:00:54 | INFO    |   CTAS 10-Q 2016-04-08: 6/6 factors scored
# 22:01:05 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:04:15 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:04:15 | ERROR   |   JSON parse error: Expecting ',' delimiter: line 1355 column 23 (char 25903). Content: {
#   "scores": [
#     {
#       "key": "margin_trajectory",
#       "label": "positive",
#       "rationale": "Gross margins are expanding due to lower energy costs and operational efficiency.",
#       "confid...
# 22:04:15 | WARNING |     Sentiment LLM returned invalid result for batch of 2
# 22:04:15 | INFO    |   CTAS 10-Q 2016-10-11: 8/10 factors scored
# 22:04:19 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:04:26 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:04:26 | INFO    |   DE 10-K 2017-12-18: 11/11 factors scored
# 22:04:29 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:04:37 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:04:37 | INFO    |   DE 10-K 2018-12-17: 11/11 factors scored
# 22:04:40 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:04:47 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:04:47 | INFO    |   DE 10-K 2019-12-19: 10/10 factors scored
# 22:04:52 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:04:55 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:04:55 | INFO    |   DE 10-K 2020-12-17: 12/12 factors scored
# 22:05:04 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:05:05 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:05:07 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:05:07 | INFO    |   DE 10-K 2021-12-16: 19/19 factors scored
# 22:05:12 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:05:18 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:05:18 | INFO    |   DE 10-K 2022-12-15: 11/11 factors scored
# 22:05:22 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:05:27 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:05:28 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:05:28 | INFO    |   DE 10-K 2023-12-15: 19/19 factors scored
# 22:05:39 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:05:39 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:05:39 | INFO    |   DE 10-K 2024-12-12: 15/15 factors scored
# 22:05:41 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:05:49 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:05:49 | INFO    |   DE 10-Q 2015-02-26: 10/10 factors scored
# 22:05:53 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:05:53 | INFO    |   DE 10-Q 2015-05-28: 4/4 factors scored
# 22:05:56 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:06:03 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:06:03 | INFO    |   DE 10-Q 2015-08-27: 10/10 factors scored
# 22:06:10 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:06:10 | INFO    |   DE 10-Q 2016-02-25: 4/4 factors scored
# 22:06:19 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:06:20 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:06:20 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:09:31 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:09:31 | ERROR   |   JSON parse error: Expecting ',' delimiter: line 1028 column 4 (char 30651). Content: {
#   "scores": [
#     {
#       "key": "long_term_strategy",
#       "label": "positive",
#       "rationale": "Clear long-term strategic direction with ongoing investments.",
#       "confidence": 0.9
#     },
#  ...
# 22:09:31 | WARNING |     Sentiment LLM returned invalid result for batch of 3
# 22:09:31 | INFO    |   DE 10-Q 2016-05-26: 24/27 factors scored
# 22:09:34 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:09:41 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:09:41 | INFO    |   DE 10-Q 2016-09-01: 10/10 factors scored
# 22:09:47 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:09:47 | INFO    |   DE 10-Q 2017-02-24: 5/5 factors scored
# 22:09:51 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:09:55 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:09:56 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:09:58 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:09:58 | INFO    |   DE 10-Q 2017-06-02: 26/27 factors scored
# 22:10:08 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:10:09 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:10:09 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:10:09 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:10:09 | INFO    |   DE 10-Q 2017-08-31: 31/31 factors scored
# 22:10:19 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:10:19 | INFO    |   DE 10-Q 2018-03-01: 5/5 factors scored
# 22:10:28 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:10:28 | ERROR   |   Pydantic validation failed: 1 validation error for SentimentBatchResponse
# scores
#   Field required [type=missing, input_value={'sentiment_labels': [{'k....', 'confidence': 0.7}]}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# 22:10:28 | WARNING |     Sentiment LLM returned invalid result for batch of 7
# 22:10:29 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:10:29 | INFO    |   DE 10-Q 2018-05-31: 8/15 factors scored
# 22:10:36 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:10:36 | ERROR   |   Pydantic validation failed: 1 validation error for SentimentBatchResponse
# scores
#   Field required [type=missing, input_value={'sentiment': {'scores': ...', 'confidence': 0.5}]}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# 22:10:36 | WARNING |     Sentiment LLM returned invalid result for batch of 5
# 22:10:39 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:10:39 | INFO    |   DE 10-Q 2018-08-30: 8/13 factors scored
# 22:10:48 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:10:49 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:10:49 | INFO    |   DE 10-Q 2019-02-28: 15/15 factors scored
# 22:10:51 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:10:58 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:10:58 | INFO    |   DE 10-Q 2019-05-30: 10/10 factors scored
# 22:11:08 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:11:09 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:11:09 | INFO    |   DE 10-Q 2019-08-29: 12/12 factors scored
# 22:11:16 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:11:16 | INFO    |   DE 10-Q 2020-02-27: 3/3 factors scored
# 22:11:20 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:11:26 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:11:26 | INFO    |   DE 10-Q 2020-05-28: 10/10 factors scored
# 22:11:36 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:11:36 | INFO    |   DE 10-Q 2020-08-27: 8/8 factors scored
# 22:11:45 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:11:46 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:11:46 | INFO    |   DE 10-Q 2021-02-25: 16/16 factors scored
# 22:11:54 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:11:56 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:11:56 | INFO    |   DE 10-Q 2021-05-27: 16/16 factors scored
# 22:12:04 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:12:06 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:12:07 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:15:18 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:15:18 | ERROR   |   JSON parse error: Expecting ',' delimiter: line 44 column 6 (char 1260). Content: {
#   "scores": [
#     {
#       "key": "demand_trends",
#       "label": "positive",
#       "rationale": "Demand is stable with a moderate increase in net sales.",
#       "confidence": 0.85
#     },
#     {
#      ...
# 22:15:18 | WARNING |     Sentiment LLM returned invalid result for batch of 8
# 22:15:18 | INFO    |   DE 10-Q 2022-02-24: 22/30 factors scored
# 22:18:38 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:18:38 | ERROR   |   JSON parse error: Expecting ',' delimiter: line 1126 column 6 (char 33611). Content: {"scores": [
#     {
#         "key": "litigation_exposure",
#         "label": "very_negative",
#         "rationale": "The company is facing significant legal challenges including class action lawsuits and ...
# 22:18:38 | WARNING |     Sentiment LLM returned invalid result for batch of 1
# 22:18:38 | INFO    |   DE 10-Q 2025-05-29: 0/1 factors scored
# 22:18:38 | WARNING |   DE 2025-05-29: 0 factors scored, skipping save
# 22:18:48 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:18:49 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:18:49 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:18:49 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:18:57 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:18:57 | INFO    |   DOV 10-K 2015-02-13: 38/38 factors scored
# 22:19:08 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:19:08 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:19:10 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:19:11 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:19:14 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:19:17 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:19:19 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:19:19 | INFO    |   DOV 10-K 2016-02-12: 49/50 factors scored
# 22:19:29 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:19:30 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:19:31 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:19:31 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:19:34 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:19:39 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:19:40 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:19:40 | INFO    |   DOV 10-K 2017-02-10: 50/50 factors scored
# 22:19:51 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:19:52 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:19:52 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:19:53 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:19:55 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:20:02 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:20:02 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:20:02 | INFO    |   DOV 10-K 2018-02-09: 50/50 factors scored
# 22:20:13 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:20:13 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:20:14 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:20:14 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:20:23 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:20:23 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:23:35 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:23:35 | ERROR   |   JSON parse error: Expecting ',' delimiter: line 200 column 28 (char 4569). Content: {
#   "scores": [
#     {
#       "key": "catalysts",
#       "label": "positive",
#       "rationale": "The company has identified several catalysts for improvement, including restructuring milestones, new pro...
# 22:23:35 | WARNING |     Sentiment LLM returned invalid result for batch of 5
# 22:23:35 | INFO    |   DOV 10-K 2019-02-15: 48/53 factors scored
# 22:23:46 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:23:47 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:23:47 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:23:51 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:23:56 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:23:58 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:26:59 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:26:59 | ERROR   |   JSON parse error: Expecting ',' delimiter: line 621 column 4 (char 26848). Content: {
#   "scores": [
#     {
#       "key": "labor_disputes",
#       "label": "negative",
#       "rationale": "Potential labor disputes pose a moderate risk to operations.",
#       "confidence": 0.8
#     },
#     {
# ...
# 22:26:59 | WARNING |     Sentiment LLM returned invalid result for batch of 8
# 22:26:59 | INFO    |   DOV 10-K 2020-02-14: 42/51 factors scored
# 22:27:09 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:27:10 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:27:12 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:27:13 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:27:13 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:27:20 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:27:20 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:27:20 | INFO    |   DOV 10-K 2021-02-12: 49/49 factors scored
# 22:27:29 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:27:29 | ERROR   |   Pydantic validation failed: 1 validation error for SentimentBatchResponse
# scores
#   Field required [type=missing, input_value={'debt_leverage': {'label...l.', 'confidence': 0.5}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# 22:27:29 | WARNING |     Sentiment LLM returned invalid result for batch of 8
# 22:27:31 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:27:31 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:27:32 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:27:34 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:27:39 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:27:42 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:27:42 | INFO    |   DOV 10-K 2022-02-11: 42/50 factors scored
# 22:27:52 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:27:53 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:27:53 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:27:54 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:28:03 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:31:16 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:31:16 | ERROR   |   JSON parse error: Expecting ',' delimiter: line 1296 column 4 (char 28855). Content: {
#   "scores": [
#     {
#       "key": "economic_conditions",
#       "label": "negative",
#       "rationale": "Mixed influences with favorable demand but significant challenges like inflation and supply cha...
# 22:31:16 | WARNING |     Sentiment LLM returned invalid result for batch of 8
# 22:31:16 | INFO    |   DOV 10-K 2023-02-10: 39/47 factors scored
# 22:31:26 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:31:27 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:31:28 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:31:28 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:31:29 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:31:36 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:31:38 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:31:38 | INFO    |   DOV 10-K 2024-02-09: 49/49 factors scored
# 22:31:48 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:31:50 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:31:50 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:31:51 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:31:58 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:32:01 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:32:01 | INFO    |   DOV 10-K 2025-02-14: 47/48 factors scored
# 22:32:09 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:32:11 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:32:12 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:32:12 | INFO    |   DOV 10-Q 2015-04-21: 21/21 factors scored
# 22:32:23 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:32:24 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:32:24 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:32:25 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:32:27 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:32:33 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:32:34 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:32:34 | INFO    |   DOV 10-Q 2015-07-21: 50/50 factors scored
# 22:32:44 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:32:45 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:32:45 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:32:45 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:32:51 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:32:54 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:32:54 | INFO    |   DOV 10-Q 2015-10-20: 45/45 factors scored
# 22:33:04 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:33:04 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:33:04 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:33:04 | INFO    |   DOV 10-Q 2016-04-21: 23/23 factors scored
# 22:33:13 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:33:14 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:33:15 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:33:15 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:33:18 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:33:25 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:33:28 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:33:28 | ERROR   |   Pydantic validation failed: 1 validation error for SentimentBatchResponse
# scores
#   Field required [type=missing, input_value={'free_cash_flow': {'scor..., 'confidence': 0.75}]}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# 22:33:28 | WARNING |     Sentiment LLM returned invalid result for batch of 8
# 22:33:28 | INFO    |   DOV 10-Q 2016-07-21: 41/50 factors scored
# 22:33:36 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:33:37 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:33:38 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:33:38 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:33:40 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:33:46 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:33:46 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:33:46 | INFO    |   DOV 10-Q 2016-10-19: 50/50 factors scored
# 22:33:55 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:33:56 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:33:57 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:33:57 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:34:00 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:34:06 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:34:07 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:34:07 | INFO    |   DOV 10-Q 2017-04-20: 50/50 factors scored
# 22:34:17 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:34:17 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:34:17 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:34:18 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:34:21 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:34:27 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:34:27 | INFO    |   DOV 10-Q 2017-07-20: 43/43 factors scored
# 22:34:36 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:34:37 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:34:38 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:34:39 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:34:41 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:34:47 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:34:48 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:34:48 | INFO    |   DOV 10-Q 2017-10-19: 49/50 factors scored
# 22:34:58 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:34:58 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:34:59 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:34:59 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:35:02 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:35:08 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:35:10 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:35:10 | INFO    |   DOV 10-Q 2018-04-27: 48/50 factors scored
# 22:35:20 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:35:21 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:35:22 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:35:23 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:35:31 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:35:31 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:38:43 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:38:43 | ERROR   |   JSON parse error: Expecting ',' delimiter: line 1571 column 4 (char 26876). Content: {
#   "scores": [
#     {
#       "key": "quality_safety",
#       "label": "very_positive",
#       "rationale": "The factor quality_safety is consistently positive with no incidents reported.",
#       "confide...
# 22:38:43 | WARNING |     Sentiment LLM returned invalid result for batch of 2
# 22:38:43 | INFO    |   DOV 10-Q 2018-07-19: 48/50 factors scored
# 22:38:53 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:38:53 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:38:54 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:38:56 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:38:58 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:38:58 | ERROR   |   Pydantic validation failed: 1 validation error for SentimentBatchResponse
# scores
#   Field required [type=missing, input_value={'sentiment_labels': {'re..., 'confidence': 0.9}]}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# 22:38:58 | WARNING |     Sentiment LLM returned invalid result for batch of 8
# 22:39:04 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:42:16 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:42:16 | ERROR   |   JSON parse error: Expecting ',' delimiter: line 1069 column 6 (char 32148). Content: {
#   "scores": [
#     {
#       "key": "forward_guidance",
#       "label": "neutral",
#       "rationale": "Mixed signals from management suggest neither clear positive nor negative outlook.",
#       "confide...
# 22:42:16 | WARNING |     Sentiment LLM returned invalid result for batch of 8
# 22:42:16 | INFO    |   DOV 10-Q 2018-10-18: 34/50 factors scored
# 22:42:25 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:42:26 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:42:26 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:42:26 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:42:29 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:42:36 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:42:36 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:42:36 | INFO    |   DOV 10-Q 2019-04-18: 50/50 factors scored
# 22:42:46 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:42:47 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:42:48 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:42:49 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:42:50 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:42:56 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:42:58 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:42:58 | INFO    |   DOV 10-Q 2019-07-18: 48/50 factors scored
# 22:43:07 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:43:08 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:43:09 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:43:11 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:43:13 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:43:18 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:43:19 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:43:19 | INFO    |   DOV 10-Q 2019-10-17: 51/51 factors scored
# 22:43:29 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:43:31 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:43:32 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:43:32 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:43:33 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:43:41 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:43:41 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:43:41 | INFO    |   DOV 10-Q 2020-04-21: 49/49 factors scored
# 22:43:52 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:43:52 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:43:53 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:43:53 | ERROR   |   Pydantic validation failed: 1 validation error for SentimentBatchResponse
# scores
#   Field required [type=missing, input_value={'sentiment_assignments':...', 'confidence': 0.95}]}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# 22:43:53 | WARNING |     Sentiment LLM returned invalid result for batch of 8
# 22:43:54 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:43:55 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:44:01 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:44:01 | ERROR   |   Pydantic validation failed: 1 validation error for SentimentBatchResponse
# scores
#   Field required [type=missing, input_value={'differentiation': {'lab...h.', 'confidence': 0.9}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# 22:44:01 | WARNING |     Sentiment LLM returned invalid result for batch of 8
# 22:44:03 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:44:03 | INFO    |   DOV 10-Q 2020-07-22: 33/49 factors scored
# 22:44:15 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:44:15 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:44:16 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:44:18 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:44:18 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:44:18 | ERROR   |   Pydantic validation failed: 1 validation error for SentimentBatchResponse
# scores
#   Field required [type=missing, input_value={'sentiment': {'demand_tr..., 'confidence': 0.8}]}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# 22:44:18 | WARNING |     Sentiment LLM returned invalid result for batch of 8
# 22:44:25 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:44:25 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:44:25 | INFO    |   DOV 10-Q 2020-10-20: 41/49 factors scored
# 22:44:36 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:44:37 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:44:39 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:44:39 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:44:40 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:44:47 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:44:48 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:44:48 | INFO    |   DOV 10-Q 2021-04-20: 48/49 factors scored
# 22:44:58 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:44:58 | ERROR   |   Pydantic validation failed: 1 validation error for SentimentBatchResponse
# scores
#   Field required [type=missing, input_value={'input_costs': {'label':....', 'confidence': 0.65}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# 22:44:58 | WARNING |     Sentiment LLM returned invalid result for batch of 8
# 22:44:59 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:45:00 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:45:01 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:45:02 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:45:08 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:45:08 | INFO    |   DOV 10-Q 2021-07-20: 34/42 factors scored
# 22:45:18 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:45:19 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:45:20 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:45:21 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:45:21 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:45:29 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:45:30 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:45:30 | INFO    |   DOV 10-Q 2021-10-19: 49/49 factors scored
# 22:45:40 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:45:40 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:45:40 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:45:43 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:45:51 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:45:52 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:49:02 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:49:02 | ERROR   |   JSON parse error: Expecting ',' delimiter: line 610 column 209 (char 37151). Content: {
#   "scores": [
#     {
#       "key": "environmental_social",
#       "label": "very_positive",
#       "rationale": "The company's initiatives in sustainable technologies and clean energy solutions are driv...
# 22:49:02 | WARNING |     Sentiment LLM returned invalid result for batch of 2
# 22:49:02 | INFO    |   DOV 10-Q 2022-04-21: 48/50 factors scored
# 22:49:12 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:49:13 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:49:16 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:49:23 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:49:24 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:52:31 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:52:31 | ERROR   |   JSON parse error: Expecting ',' delimiter: line 1125 column 4 (char 29023). Content: {
#   "scores": [
#     {
#       "key": "productivity",
#       "label": "positive",
#       "rationale": "Productivity initiatives are contributing to margin improvements despite challenges.",
#       "confiden...
# 22:52:31 | WARNING |     Sentiment LLM returned invalid result for batch of 8
# 22:52:44 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:52:44 | ERROR   |   JSON parse error: Expecting ',' delimiter: line 938 column 4 (char 35300). Content: {
#   "scores": [
#     {
#       "key": "aftermarket_service",
#       "label": "positive",
#       "rationale": "The aftermarket/service revenue is growing, driven by strong demand in certain segments, partic...
# 22:52:44 | WARNING |     Sentiment LLM returned invalid result for batch of 3
# 22:52:44 | INFO    |   DOV 10-Q 2022-07-21: 40/51 factors scored
# 22:52:52 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:52:55 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:52:55 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:52:56 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:52:58 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:53:02 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:53:04 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:53:04 | INFO    |   DOV 10-Q 2022-10-20: 48/50 factors scored
# 22:53:14 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:53:15 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:53:16 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:53:16 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:53:24 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:53:25 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:53:25 | INFO    |   DOV 10-Q 2023-04-26: 48/48 factors scored
# 22:53:35 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:53:35 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:53:36 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:53:37 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:53:43 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:53:45 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:53:45 | INFO    |   DOV 10-Q 2023-07-25: 45/46 factors scored
# 22:53:54 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:53:56 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:53:57 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:53:57 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:53:57 | ERROR   |   Pydantic validation failed: 1 validation error for SentimentBatchResponse
# scores
#   Field required [type=missing, input_value={'sentiment_scores': [{'k....', 'confidence': 0.8}]}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# 22:53:57 | WARNING |     Sentiment LLM returned invalid result for batch of 8
# 22:54:05 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:54:05 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:54:05 | INFO    |   DOV 10-Q 2023-10-24: 37/46 factors scored
# 22:54:16 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:54:16 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:54:17 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:54:17 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:54:19 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:54:26 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:54:27 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:54:27 | INFO    |   DOV 10-Q 2024-04-25: 50/50 factors scored
# 22:54:38 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:54:38 | ERROR   |   Pydantic validation failed: 1 validation error for SentimentBatchResponse
# scores
#   Field required [type=missing, input_value={'sentiment_labels': [{'k...', 'confidence': 0.85}]}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# 22:54:38 | WARNING |     Sentiment LLM returned invalid result for batch of 8
# 22:54:39 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:54:39 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:54:42 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:54:48 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:54:48 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:54:48 | INFO    |   DOV 10-Q 2024-07-25: 38/46 factors scored
# 22:54:57 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:54:57 | ERROR   |   Pydantic validation failed: 1 validation error for SentimentBatchResponse
# scores
#   Field required [type=missing, input_value={'margin_trajectory': {'l...s.', 'confidence': 0.6}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# 22:54:57 | WARNING |     Sentiment LLM returned invalid result for batch of 8
# 22:54:59 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:55:00 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:55:00 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:55:03 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:55:06 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:55:09 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:55:09 | INFO    |   DOV 10-Q 2024-10-24: 41/50 factors scored
# 22:55:19 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:55:20 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:55:21 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:55:22 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 22:55:30 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# ...
# 00:55:29 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:55:32 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:55:32 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:55:32 | ERROR   |   Pydantic validation failed: 1 validation error for SentimentBatchResponse
# scores
#   Field required [type=missing, input_value={'sentiment_labels': {'de..., 'confidence': 0.6}]}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# 00:55:32 | WARNING |     Sentiment LLM returned invalid result for batch of 8
# 00:55:32 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:55:32 | INFO    |   FDX 10-Q 2017-03-22: 23/31 factors scored
# 00:55:38 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:55:43 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:55:44 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:55:44 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:55:44 | INFO    |   FDX 10-Q 2017-09-20: 28/28 factors scored
# 00:55:53 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:55:55 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:55:55 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:55:57 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:56:02 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:56:02 | INFO    |   FDX 10-Q 2017-12-20: 38/38 factors scored
# 00:56:10 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:56:13 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:56:13 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:56:13 | INFO    |   FDX 10-Q 2018-03-21: 22/22 factors scored
# 00:56:19 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:56:24 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:56:24 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:56:24 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:56:24 | INFO    |   FDX 10-Q 2018-09-17: 27/27 factors scored
# 00:56:30 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:56:35 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:56:35 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:56:35 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:56:35 | INFO    |   FDX 10-Q 2018-12-18: 28/28 factors scored
# 00:56:45 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:56:45 | ERROR   |   Pydantic validation failed: 1 validation error for SentimentBatchResponse
# scores
#   Field required [type=missing, input_value={'sentiment': {'factors':...', 'confidence': 0.8}]}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# 00:56:45 | WARNING |     Sentiment LLM returned invalid result for batch of 8
# 00:56:46 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:56:46 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:56:47 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:56:51 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:56:51 | INFO    |   FDX 10-Q 2019-03-19: 26/37 factors scored
# 00:57:00 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:57:00 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:57:01 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:57:01 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:57:09 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:57:09 | INFO    |   FDX 10-Q 2019-09-17: 39/39 factors scored
# 00:57:20 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:57:20 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:57:21 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:57:23 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:57:23 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:57:23 | INFO    |   FDX 10-Q 2019-12-17: 33/34 factors scored
# 00:57:33 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:57:34 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:57:35 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:57:35 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:57:42 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:57:42 | INFO    |   FDX 10-Q 2020-03-17: 38/39 factors scored
# 00:57:51 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:57:53 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:57:53 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:57:53 | ERROR   |   Pydantic validation failed: 1 validation error for SentimentBatchResponse
# scores
#   Field required [type=missing, input_value={'sentiment': {'demand_tr....', 'confidence': 0.6}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# 00:57:53 | WARNING |     Sentiment LLM returned invalid result for batch of 8
# 00:57:53 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:57:53 | INFO    |   FDX 10-Q 2020-09-15: 22/30 factors scored
# 00:58:05 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:58:05 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 00:58:05 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:01:16 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:01:16 | ERROR   |   JSON parse error: Expecting ',' delimiter: line 1345 column 4 (char 27079). Content: {
#   "scores": [
#     {
#       "key": "forward_guidance",
#       "label": "positive",
#       "rationale": "The company shows strong confidence in managing liquidity and growth despite challenges.",
#       "...
# 01:01:16 | WARNING |     Sentiment LLM returned invalid result for batch of 5
# 01:01:16 | INFO    |   FDX 10-Q 2020-12-17: 24/29 factors scored
# 01:01:26 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:01:28 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:01:28 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:01:29 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:01:30 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:01:30 | INFO    |   FDX 10-Q 2021-03-18: 34/34 factors scored
# 01:01:40 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:01:41 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:01:41 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:01:41 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:01:41 | INFO    |   FDX 10-Q 2021-09-21: 31/31 factors scored
# 01:01:51 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:01:52 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:01:52 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:01:53 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:01:57 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:01:57 | INFO    |   FDX 10-Q 2021-12-16: 26/36 factors scored
# 01:02:01 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:02:07 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:02:09 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:02:09 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:02:09 | INFO    |   FDX 10-Q 2022-03-17: 26/26 factors scored
# 01:02:20 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:02:20 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:02:21 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:02:22 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:02:22 | INFO    |   FDX 10-Q 2022-09-22: 32/32 factors scored
# 01:02:32 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:02:33 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:02:33 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:02:34 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:02:34 | INFO    |   FDX 10-Q 2022-12-20: 32/32 factors scored
# 01:02:44 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:02:45 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:02:45 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:02:48 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:02:48 | ERROR   |   Pydantic validation failed: 1 validation error for SentimentBatchResponse
# scores
#   Field required [type=missing, input_value={'debt_leverage': {'score...', 'confidence': 0.6}]}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# 01:02:48 | WARNING |     Sentiment LLM returned invalid result for batch of 8
# 01:02:48 | INFO    |   FDX 10-Q 2023-03-16: 24/32 factors scored
# 01:02:59 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:03:00 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:03:01 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:03:12 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:06:11 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:06:11 | ERROR   |   JSON parse error: Expecting ',' delimiter: line 1194 column 21 (char 24330). Content: {
#   "scores": [
#     {
#       "key": "talent_retention",
#       "label": "neutral",
#       "rationale": "Talent retention is not explicitly discussed, so sentiment is neutral.",
#       "confidence": 0.8
#   ...
# 01:06:11 | WARNING |     Sentiment LLM returned invalid result for batch of 8
# 01:06:11 | INFO    |   FDX 10-Q 2023-09-20: 30/38 factors scored
# 01:06:19 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:06:21 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:06:23 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:06:23 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:06:23 | INFO    |   FDX 10-Q 2023-12-19: 26/28 factors scored
# 01:06:34 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:06:34 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:06:35 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:06:35 | ERROR   |   Pydantic validation failed: 1 validation error for SentimentBatchResponse
# scores
#   Field required [type=missing, input_value={'free_cash_flow': {'key'...d.', 'confidence': 0.5}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# 01:06:35 | WARNING |     Sentiment LLM returned invalid result for batch of 8
# 01:06:35 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:06:38 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:06:45 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:06:45 | INFO    |   FDX 10-Q 2024-03-21: 33/42 factors scored
# 01:06:55 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:06:56 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:06:57 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:06:58 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:06:58 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:07:09 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:07:09 | ERROR   |   Pydantic validation failed: 1 validation error for SentimentBatchResponse
# scores
#   Field required [type=missing, input_value={'sentiment_labels': {'de..., 'confidence': 0.6}]}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# 01:07:09 | WARNING |     Sentiment LLM returned invalid result for batch of 8
# 01:07:09 | INFO    |   FDX 10-Q 2024-09-19: 32/41 factors scored
# 01:07:20 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:07:20 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:07:21 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:07:21 | INFO    |   FDX 10-Q 2024-12-19: 23/23 factors scored
# 01:07:30 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:07:31 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:07:33 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:07:33 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:07:41 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:07:41 | INFO    | HTTP Request: POST http://127.0.0.1:8000/v1/chat/completions "HTTP/1.1 200 OK"
# 01:07:41 | INFO    |   FDX 10-Q 2025-03-20: 37/47 factors scored
#
# Done. 310 processed, 735 skipped, 7 errors
# Total factors scored: 7645
# Avg factors/filing: 24.7

# %% [markdown]
# ## Step 7: Scoring Summary
#
# Aggregate stats: total files, factors scored, per-ticker breakdown,
# label distribution, average confidence, and a sample factor with its sentiment.

# %%
from collections import Counter

# ── Aggregate stats ───────────────────────────────────────────────────────
ticker_stats = []
total_scored_files = 0
total_factors_all = 0
total_factors_with_sentiment = 0
label_counts: Counter = Counter()
all_confidences: list[float] = []

for ticker in all_tickers:
    ticker_dir = FACTORS_SCORED_DIR / ticker
    if not ticker_dir.exists():
        continue

    scored_files = sorted(ticker_dir.glob("*_factors.json"))
    n_files = len(scored_files)
    total_scored_files += n_files

    n_factors = 0
    n_scored = 0
    for sf in scored_files:
        try:
            with open(sf) as f:
                data = json.load(f)
            for fac in data.get("factors", []):
                n_factors += 1
                sentiment = fac.get("sentiment")
                if isinstance(sentiment, dict) and sentiment.get("label"):
                    n_scored += 1
                    label_counts[sentiment["label"]] += 1
                    if "confidence" in sentiment:
                        all_confidences.append(sentiment["confidence"])
        except Exception:
            pass

    total_factors_all += n_factors
    total_factors_with_sentiment += n_scored
    ticker_stats.append(
        {"ticker": ticker, "files": n_files, "factors": n_factors, "scored": n_scored}
    )

print("=" * 60)
print("SENTIMENT SCORING SUMMARY")
print(f"  Total tickers with output: {len(ticker_stats)}")
print(f"  Total scored files: {total_scored_files}")
print(f"  Total factors: {total_factors_all}")
print(f"  Factors with sentiment: {total_factors_with_sentiment}")
if total_factors_all > 0:
    pct = total_factors_with_sentiment / total_factors_all * 100
    print(f"  Scoring rate: {pct:.1f}%")

# ── Label distribution ─────────────────────────────────────────────────────
print(f"\nLabel Distribution:")
label_order = ["very_negative", "negative", "neutral", "positive", "very_positive"]
for label in label_order:
    count = label_counts.get(label, 0)
    if total_factors_with_sentiment > 0:
        pct = count / total_factors_with_sentiment * 100
        bar = "#" * int(pct / 2)
        print(f"  {label:16s}: {count:5d} ({pct:5.1f}%) {bar}")
    else:
        print(f"  {label:16s}: {count:5d}")

# ── Avg confidence ─────────────────────────────────────────────────────────
if all_confidences:
    avg_conf = sum(all_confidences) / len(all_confidences)
    print(f"\nAvg confidence: {avg_conf:.3f}")

# ── Per-ticker breakdown ──────────────────────────────────────────────────
print(f"\nPer-ticker breakdown:")
for s in sorted(ticker_stats, key=lambda x: x["files"], reverse=True)[:20]:
    print(
        f"  {s['ticker']:6s}: {s['files']:3d} files, "
        f"{s['scored']:4d}/{s['factors']:4d} factors scored"
    )
if len(ticker_stats) > 20:
    print(f"  ... and {len(ticker_stats) - 20} more tickers")

# ── Sample output ─────────────────────────────────────────────────────────
sample_file = None
for ticker in all_tickers:
    ticker_dir = FACTORS_SCORED_DIR / ticker
    if ticker_dir.exists():
        files = sorted(ticker_dir.glob("*_factors.json"))
        if files:
            sample_file = files[0]
            break

if sample_file:
    with open(sample_file) as f:
        sample = json.load(f)
    print(f"\n{'=' * 60}")
    print(f"SAMPLE: {sample_file.name}")
    print(
        f"  Ticker: {sample['ticker']}, Form: {sample['form']}, "
        f"Date: {sample['filing_date']}"
    )
    print(f"  Factors: {sample['num_factors']}")
    for fac in sample["factors"][:3]:
        print(f"\n  [{fac['category']}] {fac['key']}")
        print(f"    Summary: {fac['summary'][:120]}...")
        sentiment = fac.get("sentiment")
        if isinstance(sentiment, dict):
            print(f"    Sentiment: {sentiment.get('label')}")
            print(f"    Rationale: {sentiment.get('rationale', '')}")
            print(f"    Confidence: {sentiment.get('confidence', '')}")
        else:
            print(f"    Sentiment: {sentiment}")
    if sample["num_factors"] > 3:
        print(f"\n  ... and {sample['num_factors'] - 3} more factors")
else:
    print("\nNo scored factor files found yet. Run Step 6 first.")
# Out:
# ============================================================
# SENTIMENT SCORING SUMMARY
#   Total tickers with output: 29
#   Total scored files: 1045
#   Total factors: 33594
#   Factors with sentiment: 30332
#   Scoring rate: 90.3%
#
# Label Distribution:
#   very_negative   :  1431 (  4.7%) ##
#   negative        :  7548 ( 24.9%) ############
#   neutral         : 10312 ( 34.0%) ################
#   positive        : 10507 ( 34.6%) #################
#   very_positive   :   534 (  1.8%)
#
# Avg confidence: 0.770
#
# Per-ticker breakdown:
#   AAL   :  42 files, 1619/1774 factors scored
#   ALK   :  42 files, 1680/1841 factors scored
#   ALLE  :  42 files, 1225/1389 factors scored
#   AME   :  42 files,  933/1014 factors scored
#   AXON  :  42 files, 1130/1267 factors scored
#   AYI   :  42 files, 1176/1282 factors scored
#   BA    :  42 files, 1715/1861 factors scored
#   BLDR  :  42 files, 1267/1410 factors scored
#   CHRW  :  42 files, 1059/1167 factors scored
#   CMI   :  42 files, 1671/1864 factors scored
#   CPRT  :  42 files, 1274/1473 factors scored
#   CSX   :  42 files, 1144/1272 factors scored
#   CTAS  :  42 files,  762/ 829 factors scored
#   DAL   :  42 files, 1291/1502 factors scored
#   DOV   :  42 files, 1850/1993 factors scored
#   EFX   :  42 files,  938/1053 factors scored
#   ETN   :  42 files,  808/ 839 factors scored
#   AOS   :  41 files, 1112/1207 factors scored
#   FAST  :  41 files, 1235/1388 factors scored
#   FBIN  :  40 files,  710/ 751 factors scored
#   ... and 9 more tickers
#
# ============================================================
# SAMPLE: AAL_10-K_2015-02-25_factors.json
#   Ticker: AAL, Form: 10-K, Date: 2015-02-25
#   Factors: 34
#
#   [demand_revenue] revenue_mix
#     Summary: Revenue mix shifted towards higher-margin segments, particularly mainline passenger and other revenues....
#     Sentiment: positive
#     Rationale: Revenue mix shifted towards higher-margin segments, indicating a strategic improvement.
#     Confidence: 0.9
#
#   [labor_workforce] labor_relations
#     Summary: Labor relations are a significant risk factor with potential for strikes and disruptions....
#     Sentiment: negative
#     Rationale: Potential for strikes and disruptions poses a significant risk.
#     Confidence: 0.85
#
#   [outlook_guidance] key_sensitivities
#     Summary: Government budgets and regulatory changes are key sensitivities affecting the company's near-term results....
#     Sentiment: None
#
#   ... and 31 more factors
